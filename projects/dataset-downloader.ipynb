# %% [markdown]
# KITTI DATA SET DOWNLOAD

# %%
# !wget -P Dataset/KITTI/ https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip

# %%
# !wget -P Dataset/KITTI/ https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# Out:
# --2026-03-03 10:59:19--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 3.5.135.120, 3.5.138.205, 3.5.139.220, ...
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|3.5.135.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5601213 (5.3M) [application/zip]
# Saving to: ‘Dataset/KITTI/data_object_label_2.zip’
#
# data_object_label_2 100%[===================>]   5.34M  4.25MB/s    in 1.3s
#
# 2026-03-03 10:59:21 (4.25 MB/s) - ‘Dataset/KITTI/data_object_label_2.zip’ saved [5601213/5601213]

# %%
# !unzip Dataset/KITTI/data_object_image_2.zip
# Out:
# Archive:  Dataset/KITTI/data_object_image_2.zip
#    creating: training/image_2/
#  extracting: training/image_2/002480.png
#  extracting: training/image_2/005952.png
#  extracting: training/image_2/000709.png
#  extracting: training/image_2/000814.png
#  extracting: training/image_2/006192.png
#  extracting: training/image_2/006017.png
#  extracting: training/image_2/002731.png
#  extracting: training/image_2/005295.png
#  extracting: training/image_2/005347.png
#  extracting: training/image_2/005326.png
#  extracting: training/image_2/005713.png
#  extracting: training/image_2/007000.png
#  extracting: training/image_2/004353.png
#  extracting: training/image_2/003969.png
#  extracting: training/image_2/001973.png
#  extracting: training/image_2/001440.png
#  extracting: training/image_2/007083.png
#  extracting: training/image_2/000166.png
#  extracting: training/image_2/004479.png
#  extracting: training/image_2/003732.png
#  extracting: training/image_2/003998.png
# ...

# %%
# !unzip -d Dataset/KITTI/labels/ Dataset/KITTI/data_object_label_2.zip
# Out:
# Archive:  Dataset/KITTI/data_object_label_2.zip
#    creating: Dataset/KITTI/labels/training/label_2/
#  extracting: Dataset/KITTI/labels/training/label_2/003206.txt
#  extracting: Dataset/KITTI/labels/training/label_2/007404.txt
#  extracting: Dataset/KITTI/labels/training/label_2/005120.txt
#  extracting: Dataset/KITTI/labels/training/label_2/001692.txt
#  extracting: Dataset/KITTI/labels/training/label_2/000354.txt
#  extracting: Dataset/KITTI/labels/training/label_2/006415.txt
#  extracting: Dataset/KITTI/labels/training/label_2/003856.txt
#  extracting: Dataset/KITTI/labels/training/label_2/007427.txt
#  extracting: Dataset/KITTI/labels/training/label_2/005094.txt
#  extracting: Dataset/KITTI/labels/training/label_2/004854.txt
#  extracting: Dataset/KITTI/labels/training/label_2/004992.txt
#  extracting: Dataset/KITTI/labels/training/label_2/002109.txt
#  extracting: Dataset/KITTI/labels/training/label_2/004443.txt
#  extracting: Dataset/KITTI/labels/training/label_2/000710.txt
# ...

# %%
# !unzip -d Projects/ Projects/dataset-processor.zip
# Out:
# Archive:  Projects/dataset-processor.zip
#    creating: Projects/dataset-processor/
#   inflating: Projects/dataset-processor/requirements.txt
#    creating: Projects/dataset-processor/src/
#   inflating: Projects/dataset-processor/src/base_converter.py
#   inflating: Projects/dataset-processor/src/bbox.py
#   inflating: Projects/dataset-processor/src/citypersons_converter.py
#   inflating: Projects/dataset-processor/src/kitti_converter.py
#   inflating: Projects/dataset-processor/src/main.py
#   inflating: Projects/dataset-processor/src/utils.py
#   inflating: Projects/dataset-processor/src/__init__.py

# %% [markdown]
# City Persons Data Set Download

# %%
# !wget -P Dataset/CityPersons/ https://www.kaggle.com/api/v1/datasets/download/hakurei/citypersons
# Out:
# --2026-03-03 11:36:08--  https://www.kaggle.com/api/v1/datasets/download/hakurei/citypersons
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com:443/kaggle-data-sets/2910315/5015354/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260303%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260303T104004Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# !unzip -d Dataset/CityPersons/ Dataset/CityPersons/citypersons
# !unzip -d Dataset/CityPersons/Extracted/ Dataset/CityPersons/CityPersons

#City person is zipped inside the zip, so I am fully aware of what I am doing, this is intentional and true.
#The extracted folder will have all these
# Out:
# Archive:  Dataset/CityPersons/citypersons
#   inflating: Dataset/CityPersons/CityPersons
# Archive:  Dataset/CityPersons/CityPersons
#   inflating: Dataset/CityPersons/Extracted/GlobalWheat2020.yaml
#    creating: Dataset/CityPersons/Extracted/scripts/
#   inflating: Dataset/CityPersons/Extracted/scripts/get_imagenet.sh
#   inflating: Dataset/CityPersons/Extracted/scripts/get_coco.sh
#   inflating: Dataset/CityPersons/Extracted/scripts/download_weights.sh
#   inflating: Dataset/CityPersons/Extracted/scripts/get_coco128.sh
#   inflating: Dataset/CityPersons/Extracted/VisDrone.yaml
#    creating: Dataset/CityPersons/Extracted/images/
#   inflating: Dataset/CityPersons/Extracted/images/bus.jpg
#   inflating: Dataset/CityPersons/Extracted/images/zidane.jpg
#   inflating: Dataset/CityPersons/Extracted/ImageNet.yaml
#   inflating: Dataset/CityPersons/Extracted/VOC.yaml
#    creating: Dataset/CityPersons/Extracted/hyps/
#   inflating: Dataset/CityPersons/Extracted/hyps/hyp.scratch-med.yaml
# ...

# %% [markdown]
# EuroCity Persons

# %%
EURO_CITY_USER_NAME = ""
EURO_CITY_PASSWORD = ""

# %%
# !wget --auth-no-challenge --user="" --password="" --output-document=Dataset/EuroCity/ECP_day_img_val.zip http://eurocity-dataset.tudelft.nl//eval/downloadFiles/downloadFile/detection?file=ecpdata%2Fecpdataset_v1%2FECP_day_img_val.zip
# Out:
# --2026-03-05 11:29:00--  http://eurocity-dataset.tudelft.nl//eval/downloadFiles/downloadFile/detection?file=ecpdata%2Fecpdataset_v1%2FECP_day_img_val.zip
# Resolving eurocity-dataset.tudelft.nl (eurocity-dataset.tudelft.nl)... 131.180.122.12
# Connecting to eurocity-dataset.tudelft.nl (eurocity-dataset.tudelft.nl)|131.180.122.12|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://eurocity-dataset.tudelft.nl//eval/downloadFiles/downloadFile/detection?file=ecpdata%2Fecpdataset_v1%2FECP_day_img_val.zip [following]
# --2026-03-05 11:29:00--  https://eurocity-dataset.tudelft.nl//eval/downloadFiles/downloadFile/detection?file=ecpdata%2Fecpdataset_v1%2FECP_day_img_val.zip
# Connecting to eurocity-dataset.tudelft.nl (eurocity-dataset.tudelft.nl)|131.180.122.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9661170061 (9.0G) [application/rss+xml]
# Saving to: ‘Dataset/EuroCity/ECP_day_img_val.zip’
#
# ...

# %%
# !unzip -d Dataset/EuroCity/Extracted Dataset/EuroCity/ECP_day_img_val.zip
# Out:
# Archive:  Dataset/EuroCity/ECP_day_img_val.zip
#    creating: Dataset/EuroCity/Extracted/ECP/day/img/val/
#    creating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/
#   inflating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/amsterdam_01078.png
#   inflating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/amsterdam_01079.png
#   inflating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/amsterdam_01080.png
#   inflating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/amsterdam_01081.png
#   inflating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/amsterdam_01082.png
#   inflating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/amsterdam_01083.png
#   inflating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/amsterdam_01084.png
#   inflating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/amsterdam_01085.png
#   inflating: Dataset/EuroCity/Extracted/ECP/day/img/val/amsterdam/amsterdam_01086.png
# ...

# %%
# !wget --auth-no-challenge --user="" --password="" --output-document=Dataset/EuroCity/ECP_day_labels_val.zip http://eurocity-dataset.tudelft.nl//eval/downloadFiles/downloadFile/detection?file=ecpdata%2Fecpdataset_v1%2FECP_day_labels_val.zip
# Out:
# --2026-03-05 11:44:01--  http://eurocity-dataset.tudelft.nl//eval/downloadFiles/downloadFile/detection?file=ecpdata%2Fecpdataset_v1%2FECP_day_labels_val.zip
# Resolving eurocity-dataset.tudelft.nl (eurocity-dataset.tudelft.nl)... 131.180.122.12
# Connecting to eurocity-dataset.tudelft.nl (eurocity-dataset.tudelft.nl)|131.180.122.12|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://eurocity-dataset.tudelft.nl//eval/downloadFiles/downloadFile/detection?file=ecpdata%2Fecpdataset_v1%2FECP_day_labels_val.zip [following]
# --2026-03-05 11:44:01--  https://eurocity-dataset.tudelft.nl//eval/downloadFiles/downloadFile/detection?file=ecpdata%2Fecpdataset_v1%2FECP_day_labels_val.zip
# Connecting to eurocity-dataset.tudelft.nl (eurocity-dataset.tudelft.nl)|131.180.122.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2429421 (2.3M) [application/rss+xml]
# Saving to: ‘Dataset/EuroCity/ECP_day_labels_val.zip’
#
# ...

# %%
# !unzip -d Dataset/EuroCity/ExtractedVal/ Dataset/EuroCity/ECP_day_labels_val.zip
# Out:
# Archive:  Dataset/EuroCity/ECP_day_labels_val.zip
#    creating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/
#    creating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/amsterdam/
#   inflating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/amsterdam/amsterdam_01078.json
#   inflating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/amsterdam/amsterdam_01079.json
#   inflating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/amsterdam/amsterdam_01080.json
#   inflating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/amsterdam/amsterdam_01081.json
#   inflating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/amsterdam/amsterdam_01082.json
#   inflating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/amsterdam/amsterdam_01083.json
#   inflating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/amsterdam/amsterdam_01084.json
#   inflating: Dataset/EuroCity/ExtractedVal/ECP/day/labels/val/amsterdam/amsterdam_01085.json
# ...
